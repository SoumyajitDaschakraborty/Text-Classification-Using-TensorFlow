# %%
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_datasets as tfds

# %%
train_data, val_data, test_data = tfds.load(name="imdb_reviews", split=('train[:40%]', 'train[40%:]', 'test'), as_supervised=True)

# %%
train_data
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.int64, name=None))>

# %%
train_examples_batch, train_labels_labels = next(iter(train_data.batch(10)))

# %%
hub_layer = hub.KerasLayer("https://kaggle.com/models/google/gnews-swivel/frameworks/TensorFlow2/variations/tf2-preview-20dim/versions/1", output_shape=[20],
                           input_shape=[], dtype=tf.string, trainable= True)

# %%
model = tf.keras.Sequential()
model.add(hub_layer)
model.add(tf.keras.layers.Dense(16, activation='relu'))
model.add(tf.keras.layers.Dense(1))

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer_6 (KerasLayer)  (None, 20)                400020
#
#  dense_8 (Dense)             (None, 16)                336
#
#  dense_9 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 400373 (1.53 MB)
# Trainable params: 400373 (1.53 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
history = model.fit(train_data.shuffle(10000).batch(100), epochs =20, validation_data=val_data.batch(100), verbose=1)
# Out:
# Epoch 1/20
# 100/100 [==============================] - 5s 35ms/step - loss: 0.8580 - accuracy: 0.5792 - val_loss: 0.5949 - val_accuracy: 0.6385
# Epoch 2/20
# 100/100 [==============================] - 4s 41ms/step - loss: 0.5552 - accuracy: 0.6914 - val_loss: 0.5233 - val_accuracy: 0.7118
# Epoch 3/20
# 100/100 [==============================] - 4s 41ms/step - loss: 0.4811 - accuracy: 0.7584 - val_loss: 0.4631 - val_accuracy: 0.7691
# Epoch 4/20
# 100/100 [==============================] - 3s 29ms/step - loss: 0.4124 - accuracy: 0.8030 - val_loss: 0.4188 - val_accuracy: 0.8103
# Epoch 5/20
# 100/100 [==============================] - 5s 48ms/step - loss: 0.3506 - accuracy: 0.8439 - val_loss: 0.3773 - val_accuracy: 0.8307
# Epoch 6/20
# 100/100 [==============================] - 4s 41ms/step - loss: 0.2966 - accuracy: 0.8757 - val_loss: 0.3483 - val_accuracy: 0.8331
# Epoch 7/20
# 100/100 [==============================] - 4s 41ms/step - loss: 0.2530 - accuracy: 0.8964 - val_loss: 0.3339 - val_accuracy: 0.8599
# Epoch 8/20
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2185 - accuracy: 0.9161 - val_loss: 0.3177 - val_accuracy: 0.8640
# Epoch 9/20
# 100/100 [==============================] - 3s 29ms/step - loss: 0.1866 - accuracy: 0.9311 - val_loss: 0.3200 - val_accuracy: 0.8671
# Epoch 10/20
# 100/100 [==============================] - 3s 30ms/step - loss: 0.1617 - accuracy: 0.9450 - val_loss: 0.3088 - val_accuracy: 0.8673
# Epoch 11/20
# 100/100 [==============================] - 5s 49ms/step - loss: 0.1399 - accuracy: 0.9544 - val_loss: 0.3101 - val_accuracy: 0.8667
# Epoch 12/20
# 100/100 [==============================] - 3s 29ms/step - loss: 0.1210 - accuracy: 0.9638 - val_loss: 0.3175 - val_accuracy: 0.8703
# Epoch 13/20
# 100/100 [==============================] - 4s 41ms/step - loss: 0.1042 - accuracy: 0.9711 - val_loss: 0.3198 - val_accuracy: 0.8679
# Epoch 14/20
# 100/100 [==============================] - 3s 29ms/step - loss: 0.0887 - accuracy: 0.9748 - val_loss: 0.3299 - val_accuracy: 0.8690
# Epoch 15/20
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0772 - accuracy: 0.9806 - val_loss: 0.3366 - val_accuracy: 0.8663
# Epoch 16/20
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0649 - accuracy: 0.9859 - val_loss: 0.3484 - val_accuracy: 0.8623
# Epoch 17/20
# 100/100 [==============================] - 3s 32ms/step - loss: 0.0556 - accuracy: 0.9886 - val_loss: 0.3625 - val_accuracy: 0.8660
# Epoch 18/20
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0466 - accuracy: 0.9921 - val_loss: 0.3708 - val_accuracy: 0.8653
# Epoch 19/20
# 100/100 [==============================] - 3s 29ms/step - loss: 0.0397 - accuracy: 0.9938 - val_loss: 0.3859 - val_accuracy: 0.8644
# Epoch 20/20
# 100/100 [==============================] - 5s 49ms/step - loss: 0.0333 - accuracy: 0.9949 - val_loss: 0.3994 - val_accuracy: 0.8628

# %%
results = model.evaluate(test_data.batch(100), verbose=2)
results
# Out:
# 250/250 - 3s - loss: 0.4160 - accuracy: 0.8520 - 3s/epoch - 12ms/step
# [0.41599056124687195, 0.8520399928092957]
